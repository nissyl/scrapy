# %%
import socks,socket
socks.setdefaultproxy(socks.PROXY_TYPE_SOCKS5, "127.0.0.1", 9150)
socket.socket = socks.socksocket

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome import webdriver, options

# %%
from bs4 import BeautifulSoup

# %%
# !pip install requests
# !pip install lxml
# !pip install beautifulsoup4
# Out:
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os

# %%
os.getcwd()
# Out:
# '/anaconda3'

# %%
os.chdir("//Users/ryosuke/Desktop")

# %%
from selenium import webdriver
browser = webdriver.Chrome()
#browser = webdriver.Chrome("webdriver.chrome.driver",'C:/Users/ryosuke/Desktop/chromedriver.exe');
#browser.get('http://google.com')
#soup = BeautifulSoup(r.content, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-28-3d88f5c1b486> in <module>()
#       1 from selenium import webdriver
# ----> 2 browser = webdriver.Chrome()
#       3 #browser = webdriver.Chrome("webdriver.chrome.driver",'C:/Users/ryosuke/Desktop/chromedriver.exe');
#       4 #browser.get('http://google.com')
#       5 #soup = BeautifulSoup(r.content, 'html.parser')
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, chrome_options, service_args, desired_capabilities, service_log_path)
#      60             service_args=service_args,
#      61             log_path=service_log_path)
# ---> 62         self.service.start()
#      63
#      64         try:
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#     100             time.sleep(1)
# ...

# %%
driver = webdriver.WebDrive(executable_path='C:\anaconda3\bin\chromedriver')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-619d8efd5fbf> in <module>()
# ----> 1 driver = webdriver.WebDrive(executable_path='C:\anaconda3\bin\chromedriver')
#
# AttributeError: module 'selenium.webdriver' has no attribute 'WebDrive'

# %%
driver = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-29-2cdab8938403> in <module>()
# ----> 1 driver = webdriver.Chrome()
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, chrome_options, service_args, desired_capabilities, service_log_path)
#      60             service_args=service_args,
#      61             log_path=service_log_path)
# ---> 62         self.service.start()
#      63
#      64         try:
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#     100             time.sleep(1)
#     101             if count == 30:
# --> 102                 raise WebDriverException("Can not connect to the Service %s" % self.path)
#     103
#     104     def assert_process_still_running(self):
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
jokes = pd.read_csv('test.tsv', sep='\t', names=['id', 'joke'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-65a6a4ad2828> in <module>()
# ----> 1 jokes = pd.read_csv('test.tsv', sep='\t', names=['id', 'joke'])
#
# ...

# %%
scores = np.loadtxt('test.txt', encoding =' utf-8',delimiter=' ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-baf1c4b0850d> in <module>()
# ----> 1 scores = np.loadtxt('test.txt', encoding =' utf-8',delimiter=' ')
#
# TypeError: loadtxt() got an unexpected keyword argument 'encoding'

# %%
import sys
import json
import requests
from bs4 import BeautifulSoup

def scraping(url, output_name):
    # get a HTML response
    response = requests.get('https://shikiho.jp/tk/stock/info/3679')
    html = response.text.encode(response.encoding)  # prevent encoding errors
    # parse the response
    soup = BeautifulSoup(html, "lxml")
    # extract
    ## title
    header = soup.find("head")
    title = header.find("title").text
    ## description
    description = header.find("meta", attrs={"name": "description"})
    description_content = description.attrs['content'].text
    # output
    output = {"title": title, "description": description_content}
    # write the output as a json file
    with open(output_name, "w") as fout:
        json = json.dump(output, fout, indent=4, sort_keys=True)

# %%
data01 =[]
data02= []

for question_info in soup.find_all("div",{"class":"question"}):
    for question_name in question_info.findAll("h4",{"class":"question-title"}):
        for link in question_info.findAll('a'):
            if 'questions' in link.get("href"):
                data01.append(question_name.text)
                data02.append(link.get("href"))
                break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d27a6bb6b691> in <module>()
#       2 data02= []
#       3
# ----> 4 for question_info in soup.find_all("div",{"class":"question"}):
#       5     for question_name in question_info.findAll("h4",{"class":"question-title"}):
#       6         for link in question_info.findAll('a'):
#
# NameError: name 'soup' is not defined

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="fb: https://www.facebook.com/2008/fbml">
# <head>
# <link href="https://www.myparkinsonsteam.com/assets/prk/favicon-edbe87ffc5ae557fb5cee92a8205592b30d71b2cae0595a48a9c27e0eaf5799a.ico" rel="icon" type="image/png"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="" name="keywords"/>
# <meta content="Ask questions and get answers about Parkinson's disease from People like you. Browse questions and answers other People " name="description"/>
# <title>Parkinson's disease Questions and Answers | MyParkinsonsTeam</title>
# <script src="https://www.myparkinsonsteam.com/assets/gamanager-be5081e9128cf9fe3f786e39f0e40fe6c02d2c2bcdce5a4a0f7865ebc2fd3254.js"></script>
# <script>
# //<![CDATA[
#
#
#
# <!-- Google Analytics -->
#   HT = (typeof HT === 'undefined') ? {} : HT;
#
#   HT.gaManager = HT.gaManager || new GAManager();
# ...

# %%
data01 =[]
data02= []

for question_info in soup.find_all("div",{"class":"question"}):
    for question_name in question_info.findAll("h4",{"class":"question-title"}):
        for link in question_info.findAll('a'):
            if 'questions' in link.get("href"):
                data01.append(question_name.text)
                data02.append(link.get("href"))

# %%
data = zip(data01,data02)

# %%
data = zip(data01,data02)
with open('question_result.csv','wt',errors='backslashreplace') as fout:
    writecsv = csv.writer(fout,lineterminator='\n')
    writecsv.writerows(data)

# %%
import urllib, requests
import csv #CSVを扱えるようにするため
import re #文字列処理をしやすくするため
import time #処理を一時的に止めるため
import socks,socket #IPを偽装するため
import sys #ファイルのパスの情報を扱うため
from bs4 import BeautifulSoup #タグなどの抽出のため
from urllib.request import urlopen #情報取得のため
from requests import ConnectionError,Timeout #エラーが起きた際に回避するため
from urllib.error import HTTPError, URLError #エラーが起きた際に回避するため
from ssl import SSLError #エラーが起きた際に回避するため
import http.client #情報取得のため
import chardet #文字列を扱いやすくするライブラリ
from socks import SOCKS5Error #!pip install PySocks #エラーが起きた際に回避するため
socks.setdefaultproxy(socks.PROXY_TYPE_SOCKS5, "127.0.0.1", 9150) #IPを偽装するため
socket.socket = socks.socksocket #IPを偽装するため
sys.setrecursionlimit(10000) #処理量の多くなるようなサイトの時に取得が途中で止まらないようにするため

# %%
print(question_name.text)
# Out:
# 454 is a discontinued sequencing platform now interesting only for historical purposes or to understand its distinctive error spectrum which is seen in much of the data generated with it. Or for pe...

# %%
# !pip install selenium
# Out:
# ...
#     100% |████████████████████████████████| 942kB 827kB/s ta 0:00:01
# ...
